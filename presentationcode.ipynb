# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import numpy as np
df = np.array([[23,0,1,0,0,19], [14,1,1,3,3,7], [15,1,1,0,2,16]])
ax = sns.heatmap(df, annot=True, center=0, cmap='Blues', square=True)
ax.tick_params(left=False, bottom=False)
ax.tick_params(labelbottom=False, labelleft=False)
plt.axvline(x=3, linewidth=2, color="black", lw=3)
plt.savefig('tableheatmaprot.pdf', dpi=300)

# %%
import numpy as np
df = np.array([[29, 24], [38, 43]])
ax = sns.heatmap(df, annot=True, center=0, cmap='Blues')
ax.tick_params(left=False, bottom=False)
ax.tick_params(labelbottom=False, labelleft=False)
plt.axhline(y=1, linewidth=1, color="white", linestyle='--')
plt.axvline(x=1, linewidth=2, color="black")
plt.rcParams["figure.figsize"] = (7,3)

plt.savefig('forehandvsbackhand.pdf', dpi=300)

# %%
df = np.array([[47, 21 ,24, 45]])
ax = sns.heatmap(df, annot=True, center=0, cmap='Blues')
ax.tick_params(left=False, bottom=False)
ax.tick_params(labelbottom=False, labelleft=False)
plt.axvline(x=1, linewidth=1, color="white", linestyle='--')
plt.axvline(x=3, linewidth=1, color="white", linestyle='--')
plt.axvline(x=2, linewidth=2, color="black")
plt.rcParams["figure.figsize"] = (7,3)

plt.savefig('shortvslongrally.pdf', dpi=300)

# %%
from  matplotlib.colors import LinearSegmentedColormap
cmap=LinearSegmentedColormap.from_list('rg',["r", "w", "g"], N=256)

# %%
data = np.array([[1,-1], [-1,1]])
labels =  np.array([['TP', 'FN'], ['FP', 'TN']])
fig, ax = plt.subplots()
ax = sns.heatmap(data, annot = labels, fmt = '', cmap=cmap, cbar=False, linewidths=.5, annot_kws={"fontsize":15})
ax.xaxis.set_ticklabels(['Win','Lose'])
ax.yaxis.set_ticklabels(['Win','Lose'])
ax.set_xlabel('Predicted Outcome')
ax.set_ylabel('Actual Outcome');
plt.savefig('confusionmatrix', dpi=300)

# %%
from sklearn import svm

# %%
# importing the modules
import numpy as np
import matplotlib.pyplot as plt
 
fig, ax = plt.subplots()
# data to be plotted logistic regression train
#x = np.array([ 25,  83, 141, 199, 257])
#y = np.array([0.58181818, 0.74761016, 0.68191141, 0.6893483 , 0.70219048])
 
# plotting
plt.rcParams["figure.figsize"] = (6,4)
plt.xlabel("Training Samples")
plt.ylabel("F1 Score")
#plt.plot(x, y, color ="darkred", marker='.', markersize=10)

#logistic regression cv score
x, y = (np.array([ 25,  83, 141, 199, 257]),
 np.array([0.52896066, 0.68169277, 0.68636096, 0.67693856, 0.70524272]))
plt.plot(x, y, marker='.',markersize=10, label ='Logistic Regression')

#linear SVM train
#x,y = (np.array([ 25,  83, 141, 199, 257]),
 #np.array([0.41684211, 0.40842199, 0.55208243, 0.6773356 , 0.70040663]))
#plt.plot(x, y, color ="darkblue", marker='.',markersize=10)

#linear SVM cv score
x,y = (np.array([ 25,  83, 141, 199, 257]),
 np.array([0.38388278, 0.39802009, 0.59619775, 0.679014  , 0.69030755]))
plt.plot(x,y, marker='.',markersize=10, label='Linear SVM')

#random forest cv score
x,y = (np.array([ 25,  83, 141, 199, 257]),
 np.array([0.58394231, 0.64307692, 0.66158654, 0.65552885, 0.68755692]))
plt.plot(x,y, marker='.',markersize=10, label='Random Forest')

plt.legend()
ax.set_axisbelow(True)
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def blank_diagram(fig_width=3, fig_height=5,
                  bg_color="royalblue", color="midnightblue"):
    fig = plt.figure(figsize=(fig_width, fig_height))
    ax = fig.add_axes((0, 0, 1, 1))
    ax.set_xlim(0, fig_width)
    ax.set_ylim(0, fig_height)
    ax.set_facecolor(bg_color)

    ax.tick_params(bottom=False, top=False,
                   left=False, right=False)
    ax.tick_params(labelbottom=False, labeltop=False,
                   labelleft=False, labelright=False)

    ax.spines["top"].set_color(color)
    ax.spines["bottom"].set_color(color)
    ax.spines["left"].set_color(color)
    ax.spines["right"].set_color(color)
    ax.spines["top"].set_linewidth(2)
    ax.spines["bottom"].set_linewidth(2)
    ax.spines["left"].set_linewidth(2)
    ax.spines["right"].set_linewidth(2)

    return fig, ax

# %%
# %matplotlib inline
import json
from pandas.io.json import json_normalize
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Arc, Rectangle, ConnectionPatch
from matplotlib.offsetbox import  OffsetImage
import squarify
from functools import reduce

# %%
def draw_table(ax):
    # focus on only half of the pitch
    #Pitch Outline & Centre Line
    Table1 = Rectangle([0,0], width = 60, height = 100,color='royalblue')
    net1 = ConnectionPatch([-5,50], [65,50], "data", "data", color='black')
    Table2 = Rectangle([80,0], width = 60, height = 100,color='royalblue')
    Table3 = Rectangle([160,0], width = 60, height = 100,color='royalblue')
    Table4 = Rectangle([240,0], width = 60, height = 100,color='royalblue')
    net2 = ConnectionPatch([75,50], [145,50], "data", "data", color='black')
    net3 = ConnectionPatch([155,50], [225,50], "data", "data", color='black')
    net4 = ConnectionPatch([235,50], [305,50], "data", "data", color='black')
    
    s1 = plt.Circle((45,6),5,color="yellow")
    plt.text(43, 4.5, "S")
    s2 = plt.Circle((125,6),5,color="yellow")
    plt.text(123, 4.5, "S")
    s3 = plt.Circle((205,6),5,color="yellow")
    plt.text(203, 4.5, "S")
    s4 = plt.Circle((285,6),5,color="yellow")
    plt.text(283, 4.5, "S")
    
    l1_1 = ConnectionPatch([45,6], [35,60], "data", "data", color='grey')
    l1_2 = ConnectionPatch([125,6], [115,60], "data", "data", color='grey')
    l1_3 = ConnectionPatch([205,6], [195,60], "data", "data", color='grey')
    l1_4 = ConnectionPatch([285,6], [275,60], "data", "data", color='grey')
    
    b1_1 = plt.Circle((35,60),5,color="lime")
    plt.text(33, 58.5, "1")
    b1_2 = plt.Circle((115,60),5,color="lime")
    plt.text(113, 58.5, "1")
    b1_3 = plt.Circle((195,60),5,color="lime")
    plt.text(193, 58.5, "1")
    b1_4 = plt.Circle((275,60),5,color="lime")
    plt.text(273, 58.5, "1")
    
    l2_2 = ConnectionPatch([121,28], [115,60], "data", "data", color='grey')
    l2_3 = ConnectionPatch([201,28], [195,60], "data", "data", color='grey')
    l2_4 = ConnectionPatch([281,28], [275,60], "data", "data", color='grey')
    
    b2_2 = plt.Circle((121,28),5,color="lime")
    plt.text(119, 26.5, "2")
    b2_3 = plt.Circle((201,28),5,color="lime")
    plt.text(199, 26.5, "2")
    b2_4 = plt.Circle((281,28),5,color="lime")
    plt.text(279, 26.5, "2")
    
    l3_3 = ConnectionPatch([177,97], [201,28], "data", "data", color='grey')
    l3_4 = ConnectionPatch([257,97], [281,28], "data", "data", color='grey')
    
    b3_3 = plt.Circle((177,97),5,color="lime")
    plt.text(175, 95.5, "3")
    b3_4 = plt.Circle((257,97),5,color="lime")
    plt.text(255, 95.5, "3")

    l4_4 = ConnectionPatch([254,20], [257,97], "data", "data", color='grey')
    
    b4_4 = plt.Circle((254,20),5,color="lime")
    
    b5_4 = plt.Circle((255,18),5,color="red")
    plt.text(252, 16.5, "E")
    
    
    element = [Table1, Table2, Table3, Table4, net1, net2,net3,net4, l1_1,l1_2,l1_3,l1_4, l2_2,l2_3,l2_4,l3_3,l3_4, l4_4,
               s1,s2,s3,s4, b1_1, b1_2, b1_3, b1_4, b2_2,b2_3,b2_4,
              b3_3, b3_4, b4_4, b5_4]
    for i in element:
        ax.add_patch(i)
        

fig=plt.figure() #set up the figures
fig.set_size_inches(10, 4)
ax=fig.add_subplot(1,1,1)
draw_table(ax) #overlay our different objects on the pitch
plt.ylim(-5, 110)
plt.xlim(-15, 315)
plt.axis('off')
plt.savefig('tablesequence.pdf', dpi=300)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import scikitplot as skplt
from sklearn.model_selection import cross_val_score
from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import plot_precision_recall_curve

# %%
data = pd.read_csv('data_scaled.csv')
data
# Out:
#         SP     RP    SRP    LRP    FHP    BHP  RANK  RANKDIFF     SA    SRA  \
# 0    0.600  0.400  0.244  0.756  0.511  0.489     1 -0.062078  0.200 -0.512
# 1    0.666  0.334  0.194  0.806  0.171  0.829    12  0.062078  0.332 -0.612
# 2    0.522  0.478  0.295  0.705  0.720  0.280     3 -0.039504  0.044 -0.410
# 3    0.558  0.442  0.205  0.795  0.617  0.383    10  0.039504  0.116 -0.590
# 4    0.561  0.439  0.157  0.843  0.578  0.422     3  0.011287  0.122 -0.686
# ..     ...    ...    ...    ...    ...    ...   ...       ...    ...    ...
# 353  0.552  0.448  0.421  0.579  0.702  0.298   368  2.020364  0.104 -0.158
# 354  0.555  0.445  0.361  0.639  0.638  0.362    28 -0.152374  0.110 -0.278
# 355  0.525  0.475  0.275  0.725  0.615  0.385    55  0.152374  0.050 -0.450
# 356  0.512  0.488  0.179  0.821  0.666  0.334    10 -0.744939  0.024 -0.642
# 357  0.461  0.539  0.269  0.731  0.680  0.320   142  0.744939 -0.078 -0.462
#
#        FHA   BALANCE  WON
# 0    0.022  0.353155  1.0
# ...

# %%
columns = ['SP', 'RP', 'SRP', 'LRP', 'FHP', 'BHP', 'RANKDIFF', 'SA', 'SRA', 'FHA', 'BALANCE']
X = data[columns]
y = data.WON

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(10,7))

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=4)
model = MLPClassifier(activation='relu', hidden_layer_sizes= 2, learning_rate='constant', max_iter=200, solver='lbfgs')

model.fit(X_trainval, y_trainval)
plot_roc_curve(model, X_trainval, y_trainval, ax=axs[0,0],color='b')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=3)
model = LogisticRegression(C=1, random_state=1, solver='liblinear') 
model.fit(X_trainval, y_trainval)
plot_roc_curve(model, X_trainval, y_trainval, ax=axs[0,1],color='g')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=20)
model = SVC(C=0.2, gamma=1, kernel='linear', random_state=1) 
model.fit(X_trainval, y_trainval)
plot_roc_curve(model, X_trainval, y_trainval, ax=axs[1,0],color='r')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=9)
model =RandomForestClassifier(max_depth=80, max_features=4, min_samples_leaf=4,
                       n_estimators=200, random_state=1) 
model.fit(X_test, y_test)
plot_roc_curve(model, X_trainval, y_trainval, ax=axs[1,1],color='c')

plt.tight_layout()
plt.savefig('roccurves.pdf', dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(10,7))

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=4)
model = MLPClassifier(activation='relu', hidden_layer_sizes= 2, learning_rate='constant', max_iter=200, solver='lbfgs')

model.fit(X_trainval, y_trainval)
plot_precision_recall_curve(model, X_trainval, y_trainval, ax=axs[0,0],color='b')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=3)
model = LogisticRegression(C=1, random_state=1, solver='liblinear') 
model.fit(X_trainval, y_trainval)
plot_precision_recall_curve(model, X_trainval, y_trainval, ax=axs[0,1],color='g')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=20)
model = SVC(C=0.2, gamma=1, kernel='linear', random_state=1) 
model.fit(X_trainval, y_trainval)
plot_precision_recall_curve(model, X_trainval, y_trainval, ax=axs[1,0],color='r')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=9)
model =RandomForestClassifier(max_depth=80, max_features=4, min_samples_leaf=4,
                       n_estimators=200, random_state=1) 
model.fit(X_test, y_test)
plot_precision_recall_curve(model, X_trainval, y_trainval, ax=axs[1,1],color='c')

plt.tight_layout()
plt.savefig('precisionrecall.pdf', dpi=300)
plt.show()

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(10,7))

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=4)
model = MLPClassifier(activation='relu', hidden_layer_sizes= 2, learning_rate='constant', max_iter=200, solver='lbfgs')

model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[0,0],cmap='Blues')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=3)
model = LogisticRegression(C=1, random_state=1, solver='liblinear') 
model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[0,1],cmap='Blues')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=20)
model = SVC(C=0.2, gamma=1, kernel='linear', random_state=1) 
model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[1,0],cmap='Blues')

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=9)
model =RandomForestClassifier(max_depth=80, max_features=4, min_samples_leaf=4,
                       n_estimators=200, random_state=1) 
model.fit(X_test, y_test)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[1,1],cmap='Blues')

plt.tight_layout()
plt.savefig('roccurves.pdf', dpi=300)
plt.show()
# Out:
# /Users/sophiechiang/opt/anaconda3/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:500: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)

# %%
fig, axs = plt.subplots(nrows=2,ncols=2, figsize=(10,7))

X_trainval, X_test, y_trainval, y_test = train_test_split(X, y, train_size=0.9, random_state=20)
model = SVC(C=0.1, gamma=1,kernel='rbf', random_state=1) 
model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[0,0],cmap='Blues')


model = SVC(C=0.01, gamma=1, kernel='poly', random_state=1) 
model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[0,1],cmap='Blues')


model = SVC(C=0.3, gamma=0.1, kernel='sigmoid', random_state=1)
model.fit(X_trainval, y_trainval)
plot_confusion_matrix(model, X_trainval, y_trainval, ax=axs[1,0],cmap='Blues')


plt.tight_layout()
plt.savefig('roccurves.pdf', dpi=300)
plt.show()
